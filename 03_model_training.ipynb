# %%
# importing libraries 
import pandas as pd

# %%
# reading the dataset 
df=pd.read_csv("C:/Users/Shalabh Tripathi/Desktop/imp/ML model training/15_diabetes prediction/data/cleaned_csv")

# %%
df.head()
# Out:
#    Unnamed: 0  gender  age  hypertension  heart_disease smoking_history  \
# 0           0  Female   80             0              1           never
# 1           1  Female   54             0              0         No Info
# 2           2    Male   28             0              0           never
# 3           3  Female   36             0              0         current
# 4           4    Male   76             1              1         current
#
#      bmi  HbA1c_level  blood_glucose_level  diabetes
# 0  25.19          6.6                  140         0
# 1  27.32          6.6                   80         0
# 2  27.32          5.7                  158         0
# 3  23.45          5.0                  155         0
# 4  20.14          4.8                  155         0

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
# extracting labels and features
x=df.drop("diabetes",axis=1)
y=df["diabetes"]

# %%
# train test split 
from  sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
x_train.shape,y_train.shape
# Out:
# ((72109, 8), (72109,))

# %%
x_test.shape,y_test.shape
# Out:
# ((24037, 8), (24037,))

# %%
x_train.head(1)
# Out:
#       gender  age  hypertension  heart_disease smoking_history   bmi  \
# 5096  Female   14             0              0         No Info  21.8
#
#       HbA1c_level  blood_glucose_level
# 5096          3.5                  126

# %%
# creating pipeline 
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %%
preprocessor=ColumnTransformer(
    transformers=[
        ("OHE",OneHotEncoder(),[0,4]),
        ("scaler",StandardScaler(),[1,5,6,7])

    ],
    remainder="passthrough"
)

# %%
preprocessor
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('OHE', OneHotEncoder(), [0, 4]),
#                                 ('scaler', StandardScaler(), [1, 5, 6, 7])])

# %%
x_train_preprocessed=preprocessor.fit_transform(x_train)
x_test_preprocessed=preprocessor.transform(x_test)

# %% [markdown]
# ## Training model:

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

models = {
    "lr": LogisticRegression(),                 # Logistic Regression
    "dt": DecisionTreeClassifier(),             # Decision Tree
    "rf": RandomForestClassifier(),             # Random Forest
    "knn": KNeighborsClassifier(),              # K-Nearest Neighbors
    "svm": SVC(),                              # Support Vector Machine
    "gb": GradientBoostingClassifier()          # Gradient Boosting
}

for name,model in models.items():
    model.fit(x_train_preprocessed,y_train)
    y_preds=model.predict(x_test_preprocessed)

    print(f" {name} Accuracy score ;{accuracy_score(y_preds,y_test)}")
# Out:
#  lr Accuracy score ;0.9574406123892333
#  dt Accuracy score ;0.9490785039730416
#  rf Accuracy score ;0.9681324624537172
#  knn Accuracy score ;0.9586470857428132
#  svm Accuracy score ;0.9630985563922286
#  gb Accuracy score ;0.9705038066314432

# %% [markdown]
# Here the gradient boosting classifier works well.

# %% [markdown]
# ## Selecting model and traning

# %%
model=GradientBoostingClassifier()

# %%
model.fit(x_train_preprocessed,y_train)
# Out:
# GradientBoostingClassifier()

# %%
# pickle the file 
import pickle 
pickle.dump(model,open("model.pkl","wb"))
pickle.dump(preprocessor,open("preprocessor.pkl","wb"))
