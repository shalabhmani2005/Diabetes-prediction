# %%
# importing libraries 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px

# %%
# reading the dataset 
df=pd.read_csv("C:/Users/Shalabh Tripathi/Desktop/imp/ML model training/15_diabetes prediction/data/diabetes.csv")

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
# deleting the duplicate values 
df=df.drop_duplicates()

# %%
# converting data type of Age column 
df["age"]=df["age"].astype(int)

# %%
df.shape
# Out:
# (96146, 9)

# %% [markdown]
# ### Gender :

# %%
# count plot 
ax=sns.countplot(df,x="gender",hue="diabetes")
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
# Out:
# [Text(0, 0, '4447'), Text(0, 0, '4035')]

# %% [markdown]
# ## hypertension :

# %%
# count plot 
ax=sns.countplot(df,x="hypertension",hue="diabetes")
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
# Out:
# [Text(0, 0, '6396'), Text(0, 0, '2086')]

# %% [markdown]
# ## hypertension:

# %%
# count plot 
ax=sns.countplot(df,x="heart_disease",hue="diabetes")
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
# Out:
# [Text(0, 0, '7215'), Text(0, 0, '1267')]

# %% [markdown]
# ## smoking_history:

# %%
# count plot 
ax=sns.countplot(df,x="smoking_history",hue="diabetes")
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
# Out:
# [Text(0, 0, '3337'),
#  Text(0, 0, '1445'),
#  Text(0, 0, '948'),
#  Text(0, 0, '1590'),
#  Text(0, 0, '472'),
#  Text(0, 0, '690')]

# %%
df.head()
# Out:
#    gender  age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female   80             0              1           never  25.19
# 1  Female   54             0              0         No Info  27.32
# 2    Male   28             0              0           never  27.32
# 3  Female   36             0              0         current  23.45
# 4    Male   76             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
df.corr(numeric_only=True)["diabetes"]
# Out:
# age                    0.264927
# hypertension           0.195710
# heart_disease          0.170711
# bmi                    0.214932
# HbA1c_level            0.406408
# blood_glucose_level    0.424336
# diabetes               1.000000
# Name: diabetes, dtype: float64

# %% [markdown]
# We can easily see "HbA1c_level" and "blood_glucose_level" have maximum correlation with diabetes.

# %%
df["HbA1c_level"].unique()
# Out:
# array([6.6, 5.7, 5. , 4.8, 6.5, 6.1, 6. , 5.8, 3.5, 6.2, 4. , 4.5, 9. ,
#        7. , 8.8, 8.2, 7.5, 6.8])

# %% [markdown]
# ## diabetes:

# %%
ax=sns.countplot(df,x="diabetes")
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '87664'), Text(0, 0, '8482')]

# %%
df.shape
# Out:
# (96146, 9)

# %%
df.to_csv("cleaned_csv")
