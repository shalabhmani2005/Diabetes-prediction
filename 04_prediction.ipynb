# %%
# loading the dataset 
import pandas as pd 
import numpy as np
df=pd.read_csv("C:/Users/Shalabh Tripathi/Desktop/imp/ML model training/15_diabetes prediction/data/cleaned_csv")

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df.head()
# Out:
#    gender  age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female   80             0              1           never  25.19
# 1  Female   54             0              0         No Info  27.32
# 2    Male   28             0              0           never  27.32
# 3  Female   36             0              0         current  23.45
# 4    Male   76             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
#loading the model
import joblib

model = joblib.load("model.pkl")
preprocessor=joblib.load("preprocessor.pkl")

# %%
model
# Out:
# GradientBoostingClassifier()

# %%
preprocessor
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('OHE', OneHotEncoder(), [0, 4]),
#                                 ('scaler', StandardScaler(), [1, 5, 6, 7])])

# %% [markdown]
# # predictive system

# %%
df.iloc[89000]
# Out:
# gender                 Female
# age                        45
# hypertension                0
# heart_disease               0
# smoking_history         never
# bmi                     23.65
# HbA1c_level               6.5
# blood_glucose_level        85
# diabetes                    0
# Name: 89000, dtype: object

# %%
def prediction(gender,age,hypertension,heart_disease,smoking_history,bmi,HbA1c_level,blood_glucose_level):
    features=np.array([[gender,age,hypertension,heart_disease,smoking_history,bmi,HbA1c_level,blood_glucose_level]])
    transformed_feature=preprocessor.transform(features)
    prediction=model.predict(transformed_feature).reshape(1,-1)
    return prediction[0]

# %%
gender="Female"
age=45
hypertension=0
heart_disease=0
smoking_history="never"
bmi=23.65
HbA1c_level=6.5
blood_glucose_level=85

res=prediction(gender,age,hypertension,heart_disease,smoking_history,bmi,HbA1c_level,blood_glucose_level)
# Out:
# C:\Users\Shalabh Tripathi\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# C:\Users\Shalabh Tripathi\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
res
# Out:
# array([0], dtype=int64)

# %% [markdown]
# # Hence the model works well.
