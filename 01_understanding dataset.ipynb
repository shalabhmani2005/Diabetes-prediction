# %%
# importing libraries 
import pandas as pd

# %%
# reading the datset 
df=pd.read_csv("C:/Users/Shalabh Tripathi/Desktop/imp/ML model training/15_diabetes prediction/data/diabetes.csv")

# %%
# seeing the data 
df.sample(5)
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 28710  Female  35.0             0              0           never  22.71
# 45368  Female  48.0             0              0           never  34.20
# 92708  Female  69.0             0              0         No Info  27.32
# 28883    Male  51.0             0              0         No Info  28.35
# 12725    Male  80.0             0              0           never  27.32
#
#        HbA1c_level  blood_glucose_level  diabetes
# 28710          5.8                   80         0
# 45368          6.1                  158         0
# 92708          6.0                  145         0
# 28883          5.8                  145         0
# 12725          9.0                  240         1

# %%
# shape of the dataset 
df.shape
# Out:
# (100000, 9)

# %%
# columns present in data 
print (df.columns.to_list())
print (f"There are {len(df.columns.to_list())} columns present in this dataset")
# Out:
# ['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history', 'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes']
# There are 9 columns present in this dataset

# %%
# checking null values 
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %% [markdown]
# There is no null values in the dataset.

# %%
# checking for duplicates 
df.duplicated().sum()
# Out:
# 3854

# %% [markdown]
# There are 3854 duplcate values.

# %%
# basic info of dataset 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %% [markdown]
# Here "age" is of float data type but should be of int.

# %%
# describe function 
df.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %%
 # seeing correlation 
df.corr(numeric_only=True)
# Out:
#                           age  hypertension  heart_disease       bmi  \
# age                  1.000000      0.251171       0.233354  0.337396
# hypertension         0.251171      1.000000       0.121262  0.147666
# heart_disease        0.233354      0.121262       1.000000  0.061198
# bmi                  0.337396      0.147666       0.061198  1.000000
# HbA1c_level          0.101354      0.080939       0.067589  0.082997
# blood_glucose_level  0.110672      0.084429       0.070066  0.091261
# diabetes             0.258008      0.197823       0.171727  0.214357
#
#                      HbA1c_level  blood_glucose_level  diabetes
# age                     0.101354             0.110672  0.258008
# hypertension            0.080939             0.084429  0.197823
# heart_disease           0.067589             0.070066  0.171727
# bmi                     0.082997             0.091261  0.214357
# HbA1c_level             1.000000             0.166733  0.400660
# ...

# %% [markdown]
# ## This is the dataset on which we are going to work.
